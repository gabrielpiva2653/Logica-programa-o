# %% [markdown]
# **CALCULADORA**

# %%
nome =input("Digite seu nome: ")
print(nome)

x=int(input("Digite o valor de x: "))
print(x)

y=int(input("Digite o valor de y: "))
print(y)

soma = x + y
print(soma)

mensagem = ("O resultado da operação é:",soma)
print(mensagem)

if soma > 10:
  print("O resultado é maior que 10")
else:
  print("O resultado é menor que 10")

# %%
nome =input("Digite seu nome: ")
print(nome)

x=int(input("Digite o valor de x: "))
print(x)

y=int(input("Digite o valor de y: "))
print(y)

sub = x - y
print(sub)

mensagem = ("O resultado da operação é:",sub)
print(mensagem)

if div < 10:
  print("O resultado é menor que 10")
else:
  print("O resultado é maior que 10")
# Out:
# Digite seu nome: Gabriel
# Gabriel
# Digite o valor de x: 20
# 20
# Digite o valor de y: 10
# 10
# 10
# ('O resultado da operação é:', 10)
# O resultado é maior que 10

# %%
# Out:
# Digite seu nome: Gabriel
# Gabriel
# Digite o valor de x: 2
# 2
# Digite o valor de y: 10
# 10
# 20
# ('O resultado da operação é:', 20)
# O resultado é menor que 100

# %%
nome =input("Digite seu nome: ")
print(nome)

x=int(input("Digite o valor de x: "))
print(x)

y=int(input("Digite o valor de y: "))
print(y)

div = x / y
print(div)

mensagem = ("O resultado da operação é:",div)
print(mensagem)

if div > 100:
  print("O resultado é maior que 6")
else:
  print("O resultado é menor que 6")

# %% [markdown]
# **For**
